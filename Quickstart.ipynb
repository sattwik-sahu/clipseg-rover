# %%
import torch
import requests

# ! wget https://owncloud.gwdg.de/index.php/s/ioHbRzFx6th32hn/download -O weights.zip
# ! unzip -d weights -j weights.zip
# ! pip install git+https://github.com/openai/CLIP.git
from models.clipseg import CLIPDensePredT
from PIL import Image
from torchvision import transforms
from matplotlib import pyplot as plt

# load model
model = CLIPDensePredT(version='ViT-B/16', reduce_dim=64)
model.eval();

# non-strict, because we only stored decoder weights (not CLIP weights)
model.load_state_dict(torch.load('weights/rd64-uni.pth', map_location=torch.device('cpu')), strict=False);

# load and normalize image
input_image = Image.open('example_image.jpg')

# or load from URL...
# image_url = 'https://farm5.staticflickr.com/4141/4856248695_03475782dc_z.jpg'
# input_image = Image.open(requests.get(image_url, stream=True).raw)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.Resize((352, 352)),
])
img = transform(input_image).unsqueeze(0)

prompts = ['straight line', 'something to fill', 'wood', 'a jar']

# predict
with torch.no_grad():
    preds = model(img.repeat(4,1,1,1), prompts)[0]

# visualize prediction
_, ax = plt.subplots(1, 5, figsize=(15, 4))
[a.axis('off') for a in ax.flatten()]
ax[0].imshow(input_image)
[ax[i+1].imshow(torch.sigmoid(preds[i][0])) for i in range(4)];
[ax[i+1].text(0, -15, prompts[i]) for i in range(4)];
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-4ysbro6g
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-4ysbro6g
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packaging in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from clip==1.0) (24.0)
# Collecting regex (from clip==1.0)
#   Downloading regex-2024.5.15-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from clip==1.0) (4.66.2)
# Requirement already satisfied: torch in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from clip==1.0) (2.2.2)
# Requirement already satisfied: torchvision in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from clip==1.0) (0.17.2)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (4.11.0)
# Requirement already satisfied: sympy in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (1.12)
# Requirement already satisfied: networkx in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (3.1)
# Requirement already satisfied: jinja2 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (3.1.3)
# Requirement already satisfied: fsspec in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torch->clip==1.0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->clip==1.0) (12.4.127)
# Requirement already satisfied: numpy in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torchvision->clip==1.0) (1.24.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from torchvision->clip==1.0) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from jinja2->torch->clip==1.0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/moonlab/miniconda3/envs/pidnet/lib/python3.8/site-packages (from sympy->torch->clip==1.0) (1.3.0)
# Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 3.9 MB/s eta 0:00:00
# Downloading regex-2024.5.15-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.2/776.2 kB 8.0 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=ebe7c0d76d7106965f527bd262ed612d91f7ad5a480939a8d4183cc6ffb57881
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d6hjkh_f/wheels/ab/4f/3a/5e51521b55997aa6f0690e095c08824219753128ce8d9969a3
# Successfully built clip
# Installing collected packages: regex, ftfy, clip
# Successfully installed clip-1.0 ftfy-6.2.0 regex-2024.5.15
# 100%|███████████████████████████████████████| 335M/335M [00:51<00:00, 6.81MiB/s]

# %% [markdown]
# Load and normalize `example_image.jpg`. You can also load through an URL.

# %%
# load and normalize image
input_image = Image.open('example_image.jpg')

# or load from URL...
# image_url = 'https://farm5.staticflickr.com/4141/4856248695_03475782dc_z.jpg'
# input_image = Image.open(requests.get(image_url, stream=True).raw)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.Resize((352, 352)),
])
img = transform(input_image).unsqueeze(0)

# %% [markdown]
# Predict and visualize (this might take a few seconds if running without GPU support)

# %%
prompts = ['straight line', 'something to fill', 'wood', 'a jar']

# predict
with torch.no_grad():
    preds = model(img.repeat(4,1,1,1), prompts)[0]

# visualize prediction
_, ax = plt.subplots(1, 5, figsize=(15, 4))
[a.axis('off') for a in ax.flatten()]
ax[0].imshow(input_image)
[ax[i+1].imshow(torch.sigmoid(preds[i][0])) for i in range(4)];
[ax[i+1].text(0, -15, prompts[i]) for i in range(4)];
